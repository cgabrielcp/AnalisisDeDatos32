# %% [markdown]
# ### Comentarios
# Seccion para lectura o escritura de comentarios

# %%
print('Hola Mundo')
# Out:
# Hola Mundo

# %%
"""
    Un comentario de varias lienas
    linea 1
    linea 2

"""

print("Hello World") # Cometnario de una linea

# Bloque de print de mensajes
print("Hello World") 
print("Hello World") 
print("Hello World") 
print("Hello World")
# Out:
# Hello World
